# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\YASHASWINI\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\YASHASWINI\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\YASHASWINI\Downloads\gopuff_data.csv")

# %%
df
# Out:
#      Item Fat Content Item Identifier              Item Type  \
# 0             Regular           FDX32  Fruits and Vegetables
# 1             Low Fat           NCB42     Health and Hygiene
# 2             Regular           FDR28           Frozen Foods
# 3             Regular           FDL50                 Canned
# 4             Low Fat           DRI25            Soft Drinks
# ...               ...             ...                    ...
# 8518          low fat           NCT53     Health and Hygiene
# 8519          low fat           FDN09            Snack Foods
# 8520          low fat           DRE13            Soft Drinks
# 8521              reg           FDT50                  Dairy
# 8522              reg           FDM58            Snack Foods
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                          2012            OUT049               Tier 1
# 1                          2022            OUT018               Tier 3
# ...

# %%
df.head(11)
# Out:
#    Item Fat Content Item Identifier              Item Type  \
# 0           Regular           FDX32  Fruits and Vegetables
# 1           Low Fat           NCB42     Health and Hygiene
# 2           Regular           FDR28           Frozen Foods
# 3           Regular           FDL50                 Canned
# 4           Low Fat           DRI25            Soft Drinks
# 5           low fat           FDS52           Frozen Foods
# 6           Low Fat           NCU05     Health and Hygiene
# 7           Low Fat           NCD30              Household
# 8           Low Fat           FDW20  Fruits and Vegetables
# 9           Low Fat           FDX25                 Canned
# 10               LF           FDX21            Snack Foods
#
#     Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                        2012            OUT049               Tier 1
# 1                        2022            OUT018               Tier 3
# ...

# %%
df.tail(6)
# Out:
#      Item Fat Content Item Identifier              Item Type  \
# 8517          low fat           FDG32  Fruits and Vegetables
# 8518          low fat           NCT53     Health and Hygiene
# 8519          low fat           FDN09            Snack Foods
# 8520          low fat           DRE13            Soft Drinks
# 8521              reg           FDT50                  Dairy
# 8522              reg           FDM58            Snack Foods
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 8517                       1998            OUT027               Tier 3
# 8518                       1998            OUT027               Tier 3
# 8519                       1998            OUT027               Tier 3
# 8520                       1998            OUT027               Tier 3
# 8521                       1998            OUT027               Tier 3
# 8522                       1998            OUT027               Tier 3
#
# ...

# %%
print("size of data",df.shape)
# Out:
# size of data (8523, 12)

# %%
df.columns
# Out:
# Index(['Item Fat Content', 'Item Identifier', 'Item Type',
#        'Outlet Establishment Year', 'Outlet Identifier',
#        'Outlet Location Type', 'Outlet Size', 'Outlet Type', 'Item Visibility',
#        'Item Weight', 'Sales', 'Rating'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Item Fat Content                 str
# Item Identifier                  str
# Item Type                        str
# Outlet Establishment Year      int64
# Outlet Identifier                str
# Outlet Location Type             str
# Outlet Size                      str
# Outlet Type                      str
# Item Visibility              float64
# Item Weight                  float64
# Sales                        float64
# Rating                       float64
# dtype: object

# %% [markdown]
# ## Data Cleaning

# %%
print(df['Item Fat Content'].unique())
# Out:
# <StringArray>
# ['Regular', 'Low Fat', 'low fat', 'LF', 'reg']
# Length: 5, dtype: str

# %%
df['Item Fat Content'] = df['Item Fat Content'].replace({'LF':'Low Fat' ,'low fat':'Low Fat' ,'reg':'Regular'})

# %%
df['Item Fat Content'] = df['Item Fat Content'].replace({'regular':'Regular'})

# %%
print(df['Item Fat Content'].unique())
# Out:
# <StringArray>
# ['Regular', 'Low Fat']
# Length: 2, dtype: str

# %% [markdown]
# # Business Requirements

# %% [markdown]
# ## KPI's Requirments

# %%
# Total sales
total_sales = df['Sales'].sum()
# Avrage sales
avg_sales = df['Sales'].mean()
# no of item sold 
no_of_items_sold = df['Sales'].count() 
# Avrage rating 
avg_ratings = df['Rating'].mean()

print(f"total_sales:${total_sales:,.0F}")
print(f"avg_sales:${avg_sales:,.0F}")
print(f"no_of_items_sold:{no_of_items_sold:,.0F}")
print(f"avg_rating:{avg_ratings:,.2F}")
# Out:
# total_sales:$1,201,681
# avg_sales:$141
# no_of_items_sold:8,523
# avg_rating:3.97

# %% [markdown]
# # Chart Content

# %% [markdown]
# ## Total sales by fat content

# %%
import matplotlib.pyplot as plt
sales_by_fat = df.groupby('Item Fat Content')['Sales'].sum()
plt.pie(
    sales_by_fat,
    labels = sales_by_fat.index,
    autopct = '%.1f%%',
    startangle = 90,
     colors=['#4CAF50', '#2196F3', '#FFC107', '#F44336']
)
plt.title('Sales By Fat Content')                 
plt.axis('equal')  # ensure the pie chart is circle
plt.show()

# %%
import matplotlib.pyplot as plt
sales_by_fat = df.groupby('Item Fat Content')['Sales'].sum()
plt.pie(
    sales_by_fat,
    labels = sales_by_fat.index,
    autopct = '%.1f%%',
    startangle = 90,
         # Moves the percentages further out
    wedgeprops = {'width':0.6}      # This creates the hole (0.3 = 30% width)
)
plt.title('Sales By Fat Content')
plt.axis('equal')
plt.show()

# %% [markdown]
# # Total Sales By Item Type

# %%
import pandas as pd
import matplotlib.pyplot as plt
sales_by_type = df.groupby('Item Type')['Sales'].sum().sort_values(ascending= False)
plt.figure(figsize = (10,6))

bars = plt.bar(sales_by_type.index,sales_by_type.values,color = 'yellow')
plt.xticks(rotation = 90)
plt.xlabel('Item type')
plt.ylabel('Total sales')
plt.title('Total sales by item type')

for bar in bars:
    plt.text(
        bar.get_x()+ bar.get_width()/2,
        bar.get_height(),
        f'{bar.get_height():,.0F}',
        ha = 'center',
        va = 'bottom',
        fontsize = 7
    )
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Fat Content By Outlet For Total Sales

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
grouped = df.groupby(['Outlet Location Type','Item Fat Content'])['Sales'].sum().unstack()
grouped = grouped[['Regular','Low Fat']]
ax = grouped.plot(
    kind = 'bar',
    figsize= (8,5),
    title = 'Outlet Location Type',
    color = ['blue','grey'])
plt.xlabel ('Oulet Location Type')
plt.xlabel ('Total Sales')
plt.legend (title = 'Item Fat Content')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Total Sales By Outlet Establishment

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
sales_by_year = df.groupby('Outlet Establishment Year')['Sales'].sum().sort_index()
plt.figure(figsize=(9,5))
plt.plot(sales_by_year.index,sales_by_year.values,marker = 'o',linestyle = '-',color = 'teal')
plt.xlabel('Outlet Establishment Year') 
plt.ylabel('Total Sales')
plt.title('Outlet Establishment Year vs Total Sales')

for x,y in zip(sales_by_year.index,sales_by_year.values):
    plt.text(x,y,f'{y:,.0f}',ha = 'center',va = 'bottom',fontsize = 8)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Sales By Outlet Size

# %%
import pandas as pd 
import matplotlib.pyplot as plt

sales_by_size = df.groupby('Outlet Size')['Sales'].sum()
plt.figure(figsize=(5,5))
plt.pie(
    sales_by_size,
    labels = sales_by_size.index,
    autopct ='%1.1f%%',
    startangle = 90,
    colors = ['lightgrey','lightgreen','skyblue']
)
plt.title('Total Sales By Outlet Size')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Sales By Outlet Location

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales_by_location = (
    df.groupby('Outlet Location Type')['Sales']
    .sum()
    .reset_index()
    .sort_values('Sales',ascending = False)
)
plt.figure(figsize=(11,3))
ax = sns.barplot(
    x = 'Sales',
    y = 'Outlet Location Type',
    data = sales_by_location,
    color = 'lightpink'
)
plt.title('Total Sales By Outlet Location Type')
plt.xlabel('Total Sales')
plt.ylabel('Outlet Location Type')

plt.tight_layout()
plt.show()

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\YASHASWINI'
